# %% [markdown]
# # Mini Project 01: AI-Powered Budget Tracker
# # ISYS2001 Introduction to Business Programming
#
# **Instructions:**
# 1. Save a copy of this notebook to your Google Drive (File > Save a copy in Drive)
# 2. Rename it to include your name: `Week1_Budget_Tracker_[YourName]`
# 3. Complete all sections and code cells
# 4. Document your AI interactions as you go

# %% [markdown]
# ## Part 1: Environment Setup and First Steps

# %%
# Run this cell to test your environment
print("🎉 Welcome to ISYS2001: Introduction to Business Programming!")
print("📊 Project: Personal Finance Assistant")
print("🤖 Today's Goal: To learn about how to do coding and run the cells")

# Import datetime to timestamp your work
from datetime import datetime
print(f"\n📅 Worksheet started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# 🎉 Welcome to ISYS2001: Introduction to Business Programming!
# 📊 Project: Personal Finance Assistant
# 🤖 Today's Goal: To learn about how to do coding and run the cells
#
# 📅 Worksheet started at: 2026-02-25 11:02:52

# %% [markdown]
# ## Part 2: Your First AI Prompt
#
# Use an AI assistant (Gemini in Colab, ChatGPT, or GitHub Copilot) to create a program that:
# - Asks the user for their name
# - Asks for their monthly income
# - Prints a personalized welcome message
#
# ### 📝 Document Your AI Prompt Below:

# %%
# TASK: Write your AI prompt as a comment below
"""
My AI Prompt:
[create a python program that: Asks the user for their name
Asks for their monthly income
Prints a personalized welcome message]
"""

# Paste the AI-generated code below:
# Simple Welcome Program

# Ask for user's name
name = input("What is your name? ")

# Ask for monthly income
income = float(input("What is your monthly income? "))

# Print personalized welcome message
print("\n--- Welcome Message ---")
print(f"Hello, {name}!")
print(f"Your monthly income is ${income:.2f}.")
print("Welcome to your personal finance tracker!")
# Out:
# What is your name? Esha Pokhun
# What is your monthly income? 25000
#
# --- Welcome Message ---
# Hello, Esha Pokhun!
# Your monthly income is $25000.00.
# Welcome to your personal finance tracker!

# %% [markdown]
# ### 🔍 Evidence Package Entry #1

# %%
# Evidence Package Documentation
evidence_1 = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "context":"I wanted to create a simple input/output program to practice AI prompting",
    "ai_tool_used": "ChatGPT",
    "what_worked":"The AI understood my request and the code appreared",
    "what_didnt": "I had to clarify if the code is running",
    "what_i_learned": "I learned that specific prompts is a better accurate code for programming"
}

# Display your evidence
print("📋 EVIDENCE PACKAGE #1")
for key, value in evidence_1.items():
    print(f"{key}: {value}")
# Out:
# 📋 EVIDENCE PACKAGE #1
# timestamp: 2026-02-25 11:38:35
# context: I wanted to create a simple input/output program to practice AI prompting
# ai_tool_used: ChatGPT
# what_worked: The AI understood my request and the code appreared
# what_didnt: I had to clarify if the code is running
# what_i_learned: I learned that specific prompts is a better accurate code for programming

# %% [markdown]
# ## Part 3: Building the Budget Tracker
#
# Use AI to help you write a program that:
# - Allows users to input their monthly income
# - Allows users to input up to 3 expenses
# - Calculates remaining budget
# - Shows a warning if budget is negative
#
# ### 💡 Pro Tip: Be specific about requirements!

# %%
# TASK: Write your detailed prompt for the budget tracker
"""
My Budget Tracker Prompt:
create a program that: Allows users to input their monthly income
Allows users to input up to 3 expenses
Calculates remaining budget Shows a warning if budget is negative
"""

# %% [markdown]
# ### Paste and Test Your AI-Generated Budget Tracker

# %%
# AI-GENERATED BUDGET TRACKER CODE
# Ask for monthly income
income = float(input("Enter your monthly income: "))

# Initialize total expenses
total_expenses = 0

# Allow user to input up to 3 expenses
for i in range(1, 4):
    expense = input(f"Enter expense #{i} (or press Enter to skip): ")

    # If user presses Enter, stop asking for more expenses
    if expense == "":
        break

    total_expenses += float(expense)

# Calculate remaining budget
remaining_budget = income - total_expenses

# Display results
print("\n----- Budget Summary -----")
print(f"Total Income: ${income:.2f}")
print(f"Total Expenses: ${total_expenses:.2f}")
print(f"Remaining Budget: ${remaining_budget:.2f}")

# Show warning if budget is negative
if remaining_budget < 0:
    print("⚠️ Warning: Your budget is negative! You are overspending.")
else:
    print("✅ Good job! Your budget is within limits.")
# Out:
# Enter your monthly income: 25000
# Enter expense #1 (or press Enter to skip): 10000
# Enter expense #2 (or press Enter to skip): 15000
# Enter expense #3 (or press Enter to skip): 5000
#
# ----- Budget Summary -----
# Total Income: $25000.00
# Total Expenses: $30000.00
# Remaining Budget: $-5000.00
# ⚠️ Warning: Your budget is negative! You are overspending.

# %% [markdown]
# ### 🐛 Debugging and Refinement

# %%
# Document any issues and fixes
issues_found = [
    "Issue 1:i got no issue" ,
    "Fix 1:0 fix",
    # Add more as needed
]

print("🔧 DEBUGGING NOTES:")
for item in issues_found:
    print(f"- {item}")
# Out:
# 🔧 DEBUGGING NOTES:
# - Issue 1:i got no issue
# - Fix 1:0 fix

# %%
# REFINED VERSION - Your Working Budget Tracker
# [Paste your corrected/improved code here]

# %% [markdown]
# ## Part 4: Enhancement Challenge
#
# Choose ONE feature to add using AI assistance:
# - 🏷️ Expense categories (food, transport, entertainment)
# - 📊 Show percentage of income spent
# - ✅ Input validation (no negative numbers)
# - 📝 Detailed budget summary with advice

# %%
# Document your enhancement
enhancement_choice = "I chose to add: [Expense categories (food, transport, entertainment)]"
enhancement_prompt = "ChatGPT"
[Create a python program for Expense categories (food, transport, entertainment)]
"""

print(f"🚀 ENHANCEMENT: {Expense categories (food, transport, entertainment)}")
# Out:
# 🚀 ENHANCEMENT: I chose to add: [Expense categories (food, transport, entertainment)]

# %%
# ENHANCED BUDGET TRACKER
# Expense Categories Program

# Ask for monthly income
income = float(input("Enter your monthly income: $"))

# Ask for expenses by category
food = float(input("Enter your Food expenses: $"))
transport = float(input("Enter your Transport expenses: $"))
entertainment = float(input("Enter your Entertainment expenses: $"))

# Calculate totals
total_expenses = food + transport + entertainment
remaining_budget = income - total_expenses

# Display summary
print("\n--- Expense Summary ---")
print(f"Food: ${food:.2f}")
print(f"Transport: ${transport:.2f}")
print(f"Entertainment: ${entertainment:.2f}")
print(f"Total Expenses: ${total_expenses:.2f}")
print(f"Remaining Budget: ${remaining_budget:.2f}")

# Warning if over budget
if remaining_budget < 0:
    print("⚠️ Warning: You are over budget!")
else:
    print("✅ You are within your budget.")
# Out:
# Enter your monthly income: $25000
# Enter your Food expenses: $2000
# Enter your Transport expenses: $4000
# Enter your Entertainment expenses: $5000
#
# --- Expense Summary ---
# Food: $2000.00
# Transport: $4000.00
# Entertainment: $5000.00
# Total Expenses: $11000.00
# Remaining Budget: $14000.00
# ✅ You are within your budget.

# %% [markdown]
# ## Part 5: Reflection and Lab Exit Ticket Preparation

# %%
# Final Evidence Package Summary
evidence_2 = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "context": "Creating the full budget tracker with enhancements that will calculate my budgetary planning",
    "ai_tool_used": "ChatGPT",
    "prompts_used": 3,
    "iterations_needed": 2,
    "final_reflection": "[AI-assistant programming is very efficient type of tool, helps me to make progress in my work]"
}

print("📋 EVIDENCE PACKAGE #2 (Final)")
for key, value in evidence_2.items():
    print(f"{key}: {value}")
# Out:
# 📋 EVIDENCE PACKAGE #2 (Final)
# timestamp: 2026-02-25 12:01:36
# context: Creating the full budget tracker with enhancements that will calculate my budgetary planning
# ai_tool_used: ChatGPT
# prompts_used: 3
# iterations_needed: 2
# final_reflection: [AI-assistant programming is very efficient type of tool, helps me to make progress in my work]

# %% [markdown]
# ## 🎯 Submission Checklist
#
# Before submitting:
# - ✅ All code cells run without errors
# - ✅ You've documented at least 2 AI interactions
# - ✅ Budget tracker accepts income and 3+ expenses
# - ✅ Completed both Evidence Packages
# - ✅ Attempted the enhancement challenge
# - ✅ Reflected on your AI collaboration experience

# %%
# Generate submission summary
print("="*50)
print("WEEK 1 WORKSHEET COMPLETION SUMMARY")
print("="*50)
print(f"Student Name: [Esha Sejal Pokhun]")
print(f"Completion Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("\nCore Features Implemented:")
print("✅ Basic income/expense input")
print("✅ Budget calculation")
print("✅ Warning for negative budget")
print("✅ Enhancement: [🏷️ Expense categories (food, transport, entertainment)]")
print("\nAI Collaboration Stats:")
print(f"- AI tools used: [ChatGPT]")
print(f"- Number of prompts: 3")
print(f"- Success rate: 100%")
print("\n🎉 Ready for Lab Exit Ticket submission!")

# %% [markdown]
# ## 💭 Final Reflection Questions
#
# **1. What surprised you most about working with AI to generate code?**
# [Ai is very helpful where i can easily create a program for my workshop]
#
# **2. What makes a good prompt vs. a poor prompt?**
# [A good prompt is when we run a program is doesn't show syntax error but a poor prompt is vice versa, if a syntax error shows up, it means that it's a poor prompt]
#
# **3. How do you see AI tools fitting into your future programming workflow?**
# [AI is going to be my tool in in every class]
#
# ---
#
# ### 📁 Save and Next Steps:
# 1. File > Save a copy in GitHub (if you haven't already)
# 2. Prepare evidence for next lab session for the Exit Ticket
# 3. Start thinking about Week 2: Variables & Data Types!
